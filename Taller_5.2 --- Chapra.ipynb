# %% [markdown]
# # Taller_5.2 --- Chapra

# %%
import matplotlib.pyplot as plt 
import math
from tabulate import tabulate
# %matplotlib inline

array, tabla_2, valores, raices, Error, tabla_1, Ea_prox=[], [], [],[],[],[],[]
xReal=0.4129
fA, fB=1.0, 1.0
contador=0
xl, xu, xr, Es=0.0, 1.0, 0.0,0.1

while(contador<=4):
    fx=5*math.pow(contador,3)-5*math.pow(contador,2)+(6*contador)-2
    valores.append(contador)
    array.append(fx)
    contador+=0.07
    tabla_1.append([contador, fx])

def metodo_1(x):
    
    fBis=5*math.pow(x,3)-5*math.pow(x,2)+6*x-2
    return fBis

a=0 

while 1:
    
    xr=(xl+xu)/2
    raices.append(xr)
    fA=metodo_1(xl)
    fB=metodo_1(xr)
    erpv=math.fabs(((xReal-xr)/xReal)*100)
    
    if(a==0):
        Ea_prox.append("-----")
        ea_prx=100
    
    else:
        j=a-1
        ea_prx=math.fabs(((raices[a]-raices[j])/raices[a])*100)
        Ea_prox.append(ea_prx)
    tabla_2.append([xr, str(erpv)+" %", str(Ea_prox[a])+" %"])
    
    if ((fA*fB)<0):
        xu=xr
    
    if((fA*fB)>0):
         xl=xr
    a+=1
    
    if(ea_prx<Es):
        break

plt.title("F(x)")
plt.axis([0, 4, -10, 40])
plt.ylabel('f(x)')
plt.xlabel('x')
plt.axhline(0, color="green")
plt.plot(valores, array, 'b-')
plt.plot(xReal,0, 'rs', label='Raiz Exacta=\n0.4129')
plt.legend(loc = 'upper right', numpoints = 1)
plt.show()

print tabulate(tabla1, headers=["x", "f(x)"], tablefmt="pipe")
print "\n"
print tabulate(tablaB, headers=["Raiz","Error Relativo Porcentual", "Error Aproximado"], tablefmt="pipe")
# Out:
# |    x |       f(x) |
# |-----:|-----------:|
# | 0.07 |  -2        |
# | 0.14 |  -1.60278  |
# | 0.21 |  -1.24428  |
# | 0.28 |  -0.914195 |
# | 0.35 |  -0.60224  |
# | 0.42 |  -0.298125 |
# | 0.49 |   0.00844  |
# | 0.56 |   0.327745 |
# | 0.63 |   0.67008  |
# | 0.7  |   1.04574  |
# | 0.77 |   1.465    |
# | 0.84 |   1.93817  |
# | 0.91 |   2.47552  |
# | 0.98 |   3.08736  |
# | 1.05 |   3.78396  |
# | 1.12 |   4.57563  |
# | 1.19 |   5.47264  |
# | 1.26 |   6.4853   |
# | 1.33 |   7.62388  |
# | 1.4  |   8.89869  |
# | 1.47 |  10.32     |
# | 1.54 |  11.8981   |
# | 1.61 |  13.6433   |
# | 1.68 |  15.5659   |
# | 1.75 |  17.6762   |
# | 1.82 |  19.9844   |
# | 1.89 |  22.5008   |
# | 1.96 |  25.2358   |
# | 2.03 |  28.1997   |
# | 2.1  |  31.4026   |
# | 2.17 |  34.855    |
# | 2.24 |  38.5671   |
# | 2.31 |  42.5491   |
# | 2.38 |  46.8115   |
# | 2.45 |  51.3644   |
# | 2.52 |  56.2181   |
# | 2.59 |  61.383    |
# | 2.66 |  66.8694   |
# | 2.73 |  72.6875   |
# | 2.8  |  78.8476   |
# | 2.87 |  85.36     |
# | 2.94 |  92.235    |
# | 3.01 |  99.4829   |
# | 3.08 | 107.114    |
# | 3.15 | 115.139    |
# | 3.22 | 123.567    |
# | 3.29 | 132.409    |
# | 3.36 | 141.676    |
# | 3.43 | 151.377    |
# | 3.5  | 161.524    |
# | 3.57 | 172.125    |
# | 3.64 | 183.192    |
# | 3.71 | 194.735    |
# | 3.78 | 206.764    |
# | 3.85 | 219.289    |
# | 3.92 | 232.321    |
# | 3.99 | 245.869    |
# | 4.06 | 259.945    |
#
#
# |     Raiz | Error Relativo Porcentual   | Error Aproximado   |
# |---------:|:----------------------------|:-------------------|
# | 0.5      | 21.0946960523 %             | ----- %            |
# | 0.25     | 39.4526519738 %             | 100.0 %            |
# | 0.375    | 9.17897796077 %             | 33.3333333333 %    |
# | 0.4375   | 5.95785904577 %             | 14.2857142857 %    |
# | 0.40625  | 1.6105594575 %              | 7.69230769231 %    |
# | 0.421875 | 2.17364979414 %             | 3.7037037037 %     |
# | 0.414062 | 0.281545168322 %            | 1.88679245283 %    |
# | 0.417969 | 1.22759748123 %             | 0.934579439252 %   |
# | 0.419922 | 1.70062363768 %             | 0.46511627907 %    |
# | 0.418945 | 1.46411055946 %             | 0.2331002331 %     |
# | 0.418457 | 1.34585402034 %             | 0.116686114352 %   |
# | 0.418213 | 1.28672575079 %             | 0.0583771161705 %  |
